# %%
import os
import sys
import pandas
import glob
import multiprocessing as mlp
import easyaccess
import configparser
import argparse
import shutil
import datetime
from collections import Counter
import re

# %%
# Get a list of exposures
# Get season
# Check if they've finished in image processing pipeline
# Document and report what hasn't
# Figure out why it didn't finish it
# Build appropriate postproc.ini file
# Check if user wants to run from scratch or start wherever the pipeline failed last
# If the latter, deduce where the pipeline finished off last, set as SKIPTO flag
# Run post-processing pipeline

# %%
#check if Post-Processing folder exists. If not, clone in from github

filepath = ['../Post-Processing']
isExist = os.path.exists(filepath[0])
if isExist:
    print('Post-Processing found')
else:
    git_command = ['git clone https://github.com/SSantosLab/Post-Processing.git ../Post-Processing' ]
    print('Running'+git_command[0]+'in order to clone necessary folder post processing...')
    git_output = os.system(git_command[0])
    #check if the system command will run successfully. if it does, output will be 0 with os.system. if it doesn't, raise exception. if you got this error, try manually git cloning https://github.com/SSantosLab/gw_workflow.git one folder back in a folder called gw_workflow
    if git_output != 0:
        raise ValueError('Something went wrong with cloning Post-Processing. Please manually clone or try again.')
# Out:
# Post-Processing found

# %%
#Read file outputted from image processing to get season, nite, exposure, band
#If no file, input manually

try:
    img_proc_file = open("./image_proc_outputs/output.txt")
    lines = img_proc_file.readlines()
    
    if input('.txt file with exposures found. Would you like to use this file? (y/n): ') == ('y'):
        print('\nExtracting season, exposure, and band from sampeoutput.txt file\n')
        
        exposures = lines[0].strip()
        exposures = exposures[1:-1]
        exposures = list(exposures.split(","))

        season = lines[1].strip()

        print('Season: ' + season)
        print('Exposures: ' + str(exposures))
    
    else:
        exposures = [str(item) for item in input("Enter each exposure followed by band, separate with commas (ex. '938524 i, 938511 i, 938522 i'): ").split(',')]
        season = input('Season: ')
    
    
except:
    print('no .txt file, must input\n')
    exposures = []
    exposures_num = [str(item) for item in input("Enter each exposure separated by spaces (ex. '938524 938511 938522'): ").split(' ')]
    season = input('Season: ')
    #get exposure band
    try:
        for exposure in exposures_num:
            band_dirs = glob.glob('/pnfs/des/persistent/gw/exp/' + '*' + '/' + exposure +'/' + 'dp' + season + '/*')
            first_band_dir = str(band_dirs[:1]).split('/')[-1:]
            band_only = re.sub(r"[^a-zA-Z]+", "", str(first_band_dir))
            exposure_w_band = exposure + ' ' + band_only
            exposures.append(exposure_w_band)
    except:
        print('invalid exposures input')
    
    print('\nExposures with bands: ' + str(exposures))
# Out:
# no .txt file, must input
#
# Enter each exposure separated by spaces (ex. '938524 938511 938522'): 780622 780623 780624 780625 780633 780934 780946 780947
# Season: 2208
#
# Exposures with bands: ['780622 r', '780623 r', '780624 r', '780625 g', '780633 g', '780934 r', '780946 g', '780947 r']

# %%
# Get exposure, format: /pnfs/des/persistent/gw/exp/NITE/EXPOSURE_NUMBER/dpSEASON/BAND_CCD
# Check CCDs from image processing, check forcephoto files
# Output list of exposures that can move on to post processing

dir_prefix = '/pnfs/des/persistent/gw/exp/'
dpSeason = ('dp' + str(season) + '/')    
    
exposures_to_cont = []
bandslist = []

for exposure in exposures:
    exposure = exposure.split()
    band = exposure[1]
    exposure = exposure[0]
    
    if band not in bandslist:
        bandslist.append(band)
    
    term_size = os.get_terminal_size()
    print('=' * term_size.columns)
    print("\nFOR EXPOSURE " + str(exposure) + ":\n")
    exposure_dir = dir_prefix + '*' + '/' + exposure +'/' + dpSeason + band
    band_dirs = glob.glob(exposure_dir + '_*' + '/') #what we're counting to make sure they're all there
    print('There are '+ str(len(band_dirs)) + ' ' + str(band) + ' ccds\n')

    if glob.glob(dir_prefix + '*' + '/' + exposure +'/' + dpSeason + 'input_files'):
        print('input_files found\n')
    else:
        print('input files not found\n')
    
    complete_ccds=0
    incomplete_ccds=0
    failed_ccds=0
    complete_ccds_list = []
    fail_files = []

    for dir in band_dirs:
        if glob.glob(dir+'*.FAIL'):
            fail_file = str(glob.glob(dir+'*.FAIL'))
            fail_file = str(fail_file.split('/')[-1:])
            fail_file = fail_file.strip('[]"')
            print('ccd ' + dir[-5:-1] + ' failed on ' + fail_file)
            failed_ccds += 1
            fail_files.append(fail_file)

        elif glob.glob(dir + 'outputs_*'):
            complete_ccds += 1
            complete_ccds_list.append(dir[-5:-1])
        else:
            print('ccd ' + dir[-5:-1] + ' incomplete')
            incomplete_ccds += 1

    print('\nThere are ' + str(failed_ccds) + ' failed ' + str(band) + ' ccds')        
    print('There are ' + str(incomplete_ccds) + ' incomplete ' + str(band) + ' ccds')
    print('There are ' + str(complete_ccds) + ' complete '+ str(band) + ' ccds')

    print('\n'+str(Counter(fail_files)))
    
    if complete_ccds >= 50:
        print('\nover 50 ' + str(band) + ' ccds completed: acceptable')
        num_ccds = complete_ccds
    else:
        print('\nnot enough ccds in exposure ' + str(exposure) + ' for post processing\n')
        continue

# Get forcephoto exposure, format: /pnfs/des/persistent/gw/forcephoto/images/dpSEASON/NITE/EXPOSURE/

    expected_forcephoto_files = num_ccds * 2
    print('\nexpected forcephoto files for band ' + str(band) + ': ' + str(expected_forcephoto_files))

    forcephoto_dir_prefix = '/pnfs/des/persistent/gw/forcephoto/images/'

    forcephoto_dir = forcephoto_dir_prefix + dpSeason + '*' + '/' + exposure + '/'
    forcephoto_files = glob.glob(forcephoto_dir + '/' + '*' + '_' + str(band) + '_' + '*')
    print('found forcephoto files for exposure '+  str(exposure) + ': ' + str(len(forcephoto_files)) + '\n')
    if len(forcephoto_files) == expected_forcephoto_files: 
        print('all forcephoto files completed in exposure ' + str(exposure) + ' -> transferring to post processing\n')
        exposures_to_cont.append(exposure)
    elif len(forcephoto_files) < expected_forcephoto_files and len(forcephoto_files) > expected_forcephoto_files / 2 :
        print('some forcephoto files not yet completed in exposure ' + str(exposure) + '\n')
        exposures_to_cont.append(exposure)
        for num in complete_ccds_list:
            if not glob.glob(forcephoto_dir + '*' + str(num) + '*.fits') or not (forcephoto_dir + '*' + str(num) + '*.psf'):
                print('forcephoto files for ' + num + ' not completed / missing')
            #elif glob.glob(forcephoto_dir + '*' + num + '*.fits') and glob.glob(forcephoto_dir + '*' + num + '*.psf'):
                #print('exposure ' + num + ' completed')
        print('\nover 50% forcephoto files in exposure ' + exposure + ' completed -> transferring to post processing\n')
    elif len(forcephoto_files) < expected_forcephoto_files and not len(forcephoto_files) > expected_forcephoto_files / 2 :
        print('fewer than 50% forcephoto files completed, will not add to exposures.list')
        continue
    elif len(forcephoto_files) > expected_forcephoto_files:
        print('check: More forcephoto files than expected for this exposure -> will not add to exposures.list')
        continue
    
print('exposures moving to post processing:\n' + str(exposures_to_cont))
# Out:
# =====================================================================================================
#
# FOR EXPOSURE 780622:
#
# There are 59 r ccds
#
# input_files found
#
# ccd r_01 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_03 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_04 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_05 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_06 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_07 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_08 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_09 failed on NOOVERLAPS.FAIL'
# ccd r_10 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_11 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_12 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_13 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_14 failed on NOOVERLAPS.FAIL'
# ccd r_15 failed on NOOVERLAPS.FAIL'
# ccd r_16 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_17 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_18 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_19 failed on NOOVERLAPS.FAIL'
# ccd r_20 failed on NOOVERLAPS.FAIL'
# ccd r_21 failed on NOOVERLAPS.FAIL'
# ccd r_22 failed on NOOVERLAPS.FAIL'
# ccd r_23 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_24 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_25 failed on NOOVERLAPS.FAIL'
# ccd r_26 failed on NOOVERLAPS.FAIL'
# ccd r_27 failed on NOOVERLAPS.FAIL'
# ccd r_28 failed on NOOVERLAPS.FAIL'
# ccd r_29 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_30 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_32 failed on NOOVERLAPS.FAIL'
# ccd r_33 failed on NOOVERLAPS.FAIL'
# ccd r_34 failed on NOOVERLAPS.FAIL'
# ccd r_35 failed on NOOVERLAPS.FAIL'
# ccd r_36 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_37 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_38 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_39 failed on NOOVERLAPS.FAIL'
# ccd r_40 failed on NOOVERLAPS.FAIL'
# ccd r_41 failed on NOOVERLAPS.FAIL'
# ccd r_42 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_43 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_44 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_45 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_46 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_47 failed on NOOVERLAPS.FAIL'
# ccd r_48 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_49 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_50 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_51 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_52 failed on NOOVERLAPS.FAIL'
# ccd r_53 failed on NOOVERLAPS.FAIL'
# ccd r_54 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_55 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_56 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_57 failed on NOOVERLAPS.FAIL'
# ccd r_58 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_59 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_60 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_62 failed on RUN02_expose_makeStarCat.FAIL'
#
# There are 59 failed r ccds
# There are 0 incomplete r ccds
# There are 0 complete r ccds
#
# Counter({"RUN02_expose_makeStarCat.FAIL'": 37, "NOOVERLAPS.FAIL'": 22})
#
# not enough ccds in exposure 780622 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780623:
#
# There are 59 r ccds
#
# input_files found
#
# ccd r_01 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_03 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_04 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_05 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_06 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_07 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_08 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_09 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_10 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_11 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_12 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_13 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_14 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_15 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_16 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_17 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_18 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_19 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_20 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_21 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_22 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_23 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_24 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_25 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_26 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_27 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_28 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_29 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_30 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_32 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_33 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_34 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_35 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_36 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_37 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_38 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_39 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_40 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_41 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_42 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_43 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_44 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_45 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_46 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_47 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_48 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_49 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_50 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_51 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_52 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_53 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_54 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_55 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_56 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_57 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_58 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_59 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_60 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_62 failed on RUN02_expose_makeStarCat.FAIL'
#
# There are 59 failed r ccds
# There are 0 incomplete r ccds
# There are 0 complete r ccds
#
# Counter({"RUN02_expose_makeStarCat.FAIL'": 59})
#
# not enough ccds in exposure 780623 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780624:
#
# There are 59 r ccds
#
# input_files found
#
# ccd r_01 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_03 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_04 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_05 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_06 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_07 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_08 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_09 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_10 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_11 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_12 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_13 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_14 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_15 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_16 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_17 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_18 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_19 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_20 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_21 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_22 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_23 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_24 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_25 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_26 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_27 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_28 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_29 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_30 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_32 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_33 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_34 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_35 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_36 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_37 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_38 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_39 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_40 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_41 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_42 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_43 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_44 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_45 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_46 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_47 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_48 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_49 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_50 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_51 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_52 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_53 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_54 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_55 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_56 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_57 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_58 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_59 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_60 failed on RUN02_expose_makeStarCat.FAIL'
# ccd r_62 failed on RUN02_expose_makeStarCat.FAIL'
#
# There are 59 failed r ccds
# There are 0 incomplete r ccds
# There are 0 complete r ccds
#
# Counter({"RUN02_expose_makeStarCat.FAIL'": 59})
#
# not enough ccds in exposure 780624 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780625:
# There are 59 g ccds
#
# input_files found
#
# ccd g_01 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_03 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_04 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_05 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_06 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_07 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_08 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_09 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_10 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_11 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_12 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_13 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_14 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_15 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_16 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_17 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_18 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_19 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_20 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_21 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_22 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_23 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_24 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_25 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_26 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_27 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_28 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_29 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_30 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_32 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_33 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_34 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_35 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_36 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_37 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_38 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_39 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_40 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_41 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_42 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_43 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_44 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_45 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_46 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_47 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_48 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_49 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_50 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_51 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_52 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_53 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_54 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_55 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_56 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_57 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_58 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_59 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_60 failed on RUN02_expose_makeStarCat.FAIL'
# ccd g_62 failed on RUN02_expose_makeStarCat.FAIL'
#
# There are 59 failed g ccds
# There are 0 incomplete g ccds
# There are 0 complete g ccds
#
# Counter({"RUN02_expose_makeStarCat.FAIL'": 59})
#
# not enough ccds in exposure 780625 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780633:
#
# There are 59 g ccds
#
# input_files found
#
# ccd g_01 incomplete
# ccd g_03 incomplete
# ccd g_04 incomplete
# ccd g_05 incomplete
# ccd g_06 incomplete
# ccd g_07 incomplete
# ccd g_08 incomplete
# ccd g_09 incomplete
# ccd g_10 incomplete
# ccd g_11 incomplete
# ccd g_12 incomplete
# ccd g_13 incomplete
# ccd g_14 incomplete
# ccd g_15 incomplete
# ccd g_16 incomplete
# ccd g_17 incomplete
# ccd g_18 incomplete
# ccd g_19 incomplete
# ccd g_20 incomplete
# ccd g_21 incomplete
# ccd g_22 incomplete
# ccd g_23 incomplete
# ccd g_24 incomplete
# ccd g_25 incomplete
# ccd g_26 incomplete
# ccd g_27 incomplete
# ccd g_28 incomplete
# ccd g_29 incomplete
# ccd g_30 incomplete
# ccd g_32 incomplete
# ccd g_33 incomplete
# ccd g_34 incomplete
# ccd g_35 incomplete
# ccd g_36 incomplete
# ccd g_37 incomplete
# ccd g_38 incomplete
# ccd g_39 incomplete
# ccd g_40 incomplete
# ccd g_41 incomplete
# ccd g_42 incomplete
# ccd g_43 incomplete
# ccd g_44 incomplete
# ccd g_45 incomplete
# ccd g_46 incomplete
# ccd g_47 incomplete
# ccd g_48 incomplete
# ccd g_49 incomplete
# ccd g_50 incomplete
# ccd g_51 incomplete
# ccd g_52 incomplete
# ccd g_53 incomplete
# ccd g_54 incomplete
# ccd g_55 incomplete
# ccd g_56 incomplete
# ccd g_57 incomplete
# ccd g_58 incomplete
# ccd g_59 incomplete
# ccd g_60 incomplete
# ccd g_62 incomplete
#
# There are 0 failed g ccds
# There are 59 incomplete g ccds
# There are 0 complete g ccds
#
# Counter()
#
# not enough ccds in exposure 780633 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780934:
#
# There are 59 r ccds
#
# input_files found
#
# ccd r_01 incomplete
# ccd r_03 incomplete
# ccd r_04 incomplete
# ccd r_05 incomplete
# ccd r_06 incomplete
# ccd r_07 incomplete
# ccd r_08 incomplete
# ccd r_09 incomplete
# ccd r_10 incomplete
# ccd r_11 incomplete
# ccd r_12 incomplete
# ccd r_13 incomplete
# ccd r_14 incomplete
# ccd r_15 incomplete
# ccd r_16 incomplete
# ccd r_17 incomplete
# ccd r_18 incomplete
# ccd r_19 incomplete
# ccd r_20 incomplete
# ccd r_21 incomplete
# ccd r_22 incomplete
# ccd r_23 incomplete
# ccd r_24 incomplete
# ccd r_25 incomplete
# ccd r_26 incomplete
# ccd r_27 incomplete
# ccd r_28 incomplete
# ccd r_29 incomplete
# ccd r_30 incomplete
# ccd r_32 incomplete
# ccd r_33 incomplete
# ccd r_34 incomplete
# ccd r_35 incomplete
# ccd r_36 incomplete
# ccd r_37 incomplete
# ccd r_38 incomplete
# ccd r_39 incomplete
# ccd r_40 incomplete
# ccd r_41 incomplete
# ccd r_42 incomplete
# ccd r_43 incomplete
# ccd r_44 incomplete
# ccd r_45 incomplete
# ccd r_46 incomplete
# ccd r_47 incomplete
# ccd r_48 incomplete
# ccd r_49 incomplete
# ccd r_50 incomplete
# ccd r_51 incomplete
# ccd r_52 incomplete
# ccd r_53 incomplete
# ccd r_54 incomplete
# ccd r_55 incomplete
# ccd r_56 incomplete
# ccd r_57 incomplete
# ccd r_58 incomplete
# ccd r_59 incomplete
# ccd r_60 incomplete
# ccd r_62 incomplete
#
# There are 0 failed r ccds
# There are 59 incomplete r ccds
# There are 0 complete r ccds
#
# Counter()
#
# not enough ccds in exposure 780934 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780946:
#
# There are 59 g ccds
#
# input_files found
#
# ccd g_01 incomplete
# ccd g_03 incomplete
# ccd g_04 incomplete
# ccd g_05 incomplete
# ccd g_06 incomplete
# ccd g_07 incomplete
# ccd g_08 incomplete
# ccd g_09 incomplete
# ccd g_10 incomplete
# ccd g_11 incomplete
# ccd g_12 incomplete
# ccd g_13 incomplete
# ccd g_14 incomplete
# ccd g_15 incomplete
# ccd g_16 incomplete
# ccd g_17 incomplete
# ccd g_18 incomplete
# ccd g_19 incomplete
# ccd g_20 incomplete
# ccd g_21 incomplete
# ccd g_22 incomplete
# ccd g_23 incomplete
# ccd g_24 incomplete
# ccd g_25 incomplete
# ccd g_26 incomplete
# ccd g_27 incomplete
# ccd g_28 incomplete
# ccd g_29 incomplete
# ccd g_30 incomplete
# ccd g_32 incomplete
# ccd g_33 incomplete
# ccd g_34 incomplete
# ccd g_35 incomplete
# ccd g_36 incomplete
# ccd g_37 incomplete
# ccd g_38 incomplete
# ccd g_39 incomplete
# ccd g_40 incomplete
# ccd g_41 incomplete
# ccd g_42 incomplete
# ccd g_43 incomplete
# ccd g_44 incomplete
# ccd g_45 incomplete
# ccd g_46 incomplete
# ccd g_47 incomplete
# ccd g_48 incomplete
# ccd g_49 incomplete
# ccd g_50 incomplete
# ccd g_51 incomplete
# ccd g_52 incomplete
# ccd g_53 incomplete
# ccd g_54 incomplete
# ccd g_55 incomplete
# ccd g_56 incomplete
# ccd g_57 incomplete
# ccd g_58 incomplete
# ccd g_59 incomplete
# ccd g_60 incomplete
# ccd g_62 incomplete
#
# There are 0 failed g ccds
# There are 59 incomplete g ccds
# There are 0 complete g ccds
#
# Counter()
#
# not enough ccds in exposure 780946 for post processing
#
# =====================================================================================================
#
# FOR EXPOSURE 780947:
#
# There are 59 r ccds
#
# input_files found
#
# ccd r_01 incomplete
# ccd r_03 incomplete
# ccd r_04 incomplete
# ccd r_05 incomplete
# ccd r_06 incomplete
# ccd r_07 incomplete
# ccd r_08 incomplete
# ccd r_09 incomplete
# ccd r_10 incomplete
# ccd r_11 incomplete
# ccd r_12 incomplete
# ccd r_13 incomplete
# ccd r_14 incomplete
# ccd r_15 incomplete
# ccd r_16 incomplete
# ccd r_17 incomplete
# ccd r_18 incomplete
# ccd r_19 incomplete
# ccd r_20 incomplete
# ccd r_21 incomplete
# ccd r_22 incomplete
# ccd r_23 incomplete
# ccd r_24 incomplete
# ccd r_25 incomplete
# ccd r_26 incomplete
# ccd r_27 incomplete
# ccd r_28 incomplete
# ccd r_29 incomplete
# ccd r_30 incomplete
# ccd r_32 incomplete
# ccd r_33 incomplete
# ccd r_34 incomplete
# ccd r_35 incomplete
# ccd r_36 incomplete
# ccd r_37 incomplete
# ccd r_38 incomplete
# ccd r_39 incomplete
# ccd r_40 incomplete
# ccd r_41 incomplete
# ccd r_42 incomplete
# ccd r_43 incomplete
# ccd r_44 incomplete
# ccd r_45 incomplete
# ccd r_46 incomplete
# ccd r_47 incomplete
# ccd r_48 incomplete
# ccd r_49 incomplete
# ccd r_50 incomplete
# ccd r_51 incomplete
# ccd r_52 incomplete
# ccd r_53 incomplete
# ccd r_54 incomplete
# ccd r_55 incomplete
# ccd r_56 incomplete
# ccd r_57 incomplete
# ccd r_58 incomplete
# ccd r_59 incomplete
# ccd r_60 incomplete
# ccd r_62 incomplete
#
# There are 0 failed r ccds
# There are 59 incomplete r ccds
# There are 0 complete r ccds
#
# Counter()
#
# not enough ccds in exposure 780947 for post processing
#
# exposures moving to post processing:
# []

# %%
#create custom exposure.list file

print('creating .list file for completed exposures\n')

current_exposures = 'complete_exposures' + '_S' + str(season) + '_' + str(datetime.datetime.now().strftime("%Y%m%d_%H-%M")) + '.list'
with open(current_exposures, 'w') as f:
    for exposure in exposures_to_cont:
        f.write("%s\n" % exposure)
# Out:
# creating .list file for completed exposures

# %%
#create .ini file


#ask user for

ligoid = input('ligoid (ex. GW170814): ')
triggerid = input('triggerid (ex. G298048): ')
propid = input('propid (ex. 2017B-0110): ')
triggermjd = input('triggermjd (ex. 57979.437): ')

print('creating .ini file with completed exposures list\n')

exposures_listfile = str(current_exposures)

shutil.copyfile('template_postproc.ini', 'postproc_' + str(season) + '.ini')
postproc_season_file = 'postproc_'+ str(season) + '.ini'

edit = configparser.ConfigParser()
edit.read(postproc_season_file)

general = edit["general"]
general["season"] = season
general["ligoid"] = ligoid
general["triggerid"] = triggerid
general["propid"] = propid
general["triggermjd"] = triggermjd
general["exposures_listfile"] = exposures_listfile

#editing bandslist
bandslist = str(bandslist)
bandslist = bandslist.strip("[]'")
bandslist = bandslist.replace("'","")
bandslist += ' ;'

general["bands"] = str(bandslist)

with open(postproc_season_file, 'w') as configfile:
    edit.write(configfile)

# %%
#fetching directories from .ini file for SKIPTO

outdir = general["outdir"] 

truthtable = edit["truthtable"]
truthplusfile = truthtable['plusname']

# %%
#Check if we want to SKIPTO

if glob.glob('../Post-Processing/'+ outdir[2:] + '/makedatafiles/LightCurvesReal/*.dat'):
    skip = input('It seems step 5 run_postproc has already been completed, would you like to skip to step 6? (y/n): ')
    if skip == ('y'):
        SKIPTO_flag = 6
        print('\nWill run post processing from step 6')
    else:
        print('\nWill run post processing from scratch')
elif os.path.exists('../Post-Processing/' + outdir[2:] + '/truthtable'+str(season)+'/'+truthplusfile): #output from step 4
    skip = input('\nIt seems step 4 run_postproc has already been completed, would you like to skip to step 5? (y/n): ')
    if skip == ('y'):
        SKIPTO_flag = 5
    else:
        print('Will run post processing from step 5')
else:
    print('No evidence of steps already completed in post processing, will not skip')

print('\nContinuing to post processing')

# %%
#move .ini file and exposures list into Post-Processing

os.system('mv ' + str(postproc_season_file) + ' ../Post-Processing')
os.system('mv ' + str(current_exposures) + ' ../Post-Processing')

#setup for Post Processing
os.system('source ../Post-Processing/diffimg_setup.sh')
print('running diffimg_setup.sh\n')

update_forcephoto_links = input('Are you running post processing for new exposures? (aka: run ./update_forcephoto_links.sh?) y/n: ')
if update_forcephoto_links == ('y'):
    os.system('../Post-Processing/update_forcephoto_links.sh')
    
#run_postproc.py

try:
    SKIPTO_flag
except NameError:
    print("\nRunning run_postproc.py\n")
    os.system('nohup python ../Post-Processing/run_postproc.py --outputdir outdir --season '+ str(season)+ ' &> postproc_run.out &')
else:
    print("\nRunning run_postproc.py with skip\n")
    os.system('nohup python ../Post-Processing/run_postproc.py --SKIPTO ' + str(SKIPTO_flag) + ' --outputdir outdir --season '+ str(season)+ ' &> postproc_run.out &')

# %%
#make cuts
